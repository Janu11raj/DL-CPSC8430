# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torch.nn.utils import parameters_to_vector, vector_to_parameters
from torch.autograd import Variable
import pandas as pd

# %%
# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=False)

test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

print("train_dataset size:", len(train_dataset),"\ntest_dataset size:", len(test_dataset))
# Out:
# train_dataset size: 60000
# test_dataset size: 10000

# %%
# Data loader func
def train_loader(batch_size):
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size = batch_size, 
                                           shuffle=True)
    return train_loader


def test_loader(batch_size):
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)
    return test_loader

# %%
class Model(nn.Module):
  def __init__(self,):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(784, 500)
        self.fc2 = nn.Linear(500, 10)
        
  def forward(self, x):
        # flatten as one dimension
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
#train function
def trainFunc(model,num_epochs,train_batch_size):
    model.train()
    print('strated')
    train_load = train_loader(train_batch_size)
    n_total_steps = len(train_load)
    train_losses = []
    train_epoch = []
    train_acc = []
    not_converged =True
    epoch = 0
    sensitivity=[]
    while not_converged:
        epoch += 1
        n_correct = 0
        n_samples = 0
        lossSum =0
        for i, (images, labels) in enumerate(train_load):  
            #if (i+1)% 60 == 0 : print(i+1)
            images, labels = Variable(images),Variable(labels)
            
            optimizer.zero_grad()
            
            # Forward pass
            prediction = model(images)

            images.requires_grad = True

            loss = loss_func(prediction, labels)
            lossSum += loss

            # Backward and optimize
            loss.backward()
            optimizer.step()

            #Calculation for sensitivity
            froGrad=0
            count =0 
            
        
            for p in model.parameters():
                grad = 0.0
                if p.grad is not None:
                    grad = p.grad
                    froGrad_norm = torch.linalg.norm(grad).numpy()
                    froGrad += froGrad_norm
                    count += 1
            
            sensitivity.append(froGrad/count)

            
            #loss.backward()
            
            #optimizer.step()

            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            acc = 100.0 * n_correct / n_samples

            train_losses.append(loss.item())
            train_acc.append(acc)
            train_epoch.append(epoch)
        

            if (i+1) % 10 == 0:
                print (f'Train O/P: Epoch [{epoch}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}',end= '\r',flush = True)
                if epoch == num_epochs:
                        print("Max Epoch Reached")
                        not_converged = False
                elif (epoch > 5) and  (train_losses[-1] < 0.001):
                    if abs(train_losses[-3] - train_losses[-2]) < 1.0e-05 and abs(train_losses[-2] - train_losses[-1]) < 1.0e-05:
                        print("Convergeance reached for loss:",train_losses[-1])
                        not_converged = False
                        
        trainAvgLoss = lossSum/i+1
        print("Train Avg loss:",trainAvgLoss)
                        
    return train_epoch,train_losses,train_acc,sensitivity,trainAvgLoss

# %%
import copy

# %%
batchArr = np.linspace (10,1510,5)
print(batchArr)
# Out:
# [  10.  385.  760. 1135. 1510.]

# %%
def testFunction(model,loss_func,test_batch_size): 
    test_load = test_loader(test_batch_size)
    model.eval()
    with torch.no_grad():
        n_correct = 0
        n_samples = 0
        testLoss = 0
        count = 0
        for images, labels in test_load:
            images, labels = Variable(images),Variable(labels)
            
            prediction = model(images)
            testLoss += loss_func(prediction,labels).item()
            # max returns (value ,index)
            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            count += 1
    netTest_loss = testLoss/count
    netTest_acc1 = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the test images: {netTest_acc1}% & Test Loss: {netTest_loss} ',end= '\r',flush = True)
    return netTest_acc1, netTest_loss

# %%
modelsTrainEpochArr = []
modelsTrainLossArr = []
modelsTrainAccArr = []
modelsTestLossArr = []
modelsTestAccArr = []
modelsSensitivityArr = []

temModel = Model ()

a=[]
for k in temModel.parameters():
    a.append(torch.numel(k))

print(f'Total no of parameters in Model :{np.sum(a)}')

for i in range (len(batchArr)):
    torch.manual_seed(1)
    
    j=copy.deepcopy(i) 
    j = Model()
    loss_func = nn.CrossEntropyLoss()
    #optimizer = torch.optim.SGD(j.parameters(), lr=0.0004, momentum= 0.5)
    optimizer = torch.optim.Adam(j.parameters(), lr=1e-3, weight_decay= 1e-4)


    max_epochs = 5
    train_batch_size = int(batchArr[i])

    train_epoch,train_losses,train_acc,sensitivity,tvgLoss = trainFunc(j,max_epochs,train_batch_size)

    test_batch_size = int(batchArr[i])

    testAcc, testLoss = testFunction(j,loss_func,test_batch_size)

    #sensitivity = sensitivityFunc(j)
    
    modelsTrainEpochArr.append(train_epoch)
    modelsTrainLossArr.append(train_losses)
    modelsTrainAccArr.append(train_acc)
    modelsTestAccArr.append(testAcc)
    modelsTestLossArr.append(testLoss)
    modelsSensitivityArr.append(sensitivity)
# Out:
# Total no of parameters in Model :397510
# strated
# Train Avg loss: tensor(1.1960, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.0900, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.0717, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.0634, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/6000], Loss: 0.0919
# Max Epoch Reached[5/5], Step [20/6000], Loss: 0.0053
# Max Epoch Reached[5/5], Step [30/6000], Loss: 0.0033
# Max Epoch Reached[5/5], Step [40/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [50/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [60/6000], Loss: 0.0053
# Max Epoch Reached[5/5], Step [70/6000], Loss: 0.0345
# Max Epoch Reached[5/5], Step [80/6000], Loss: 0.0040
# Max Epoch Reached[5/5], Step [90/6000], Loss: 0.1348
# Max Epoch Reached[5/5], Step [100/6000], Loss: 0.1845
# Max Epoch Reached[5/5], Step [110/6000], Loss: 0.0162
# Max Epoch Reached[5/5], Step [120/6000], Loss: 0.0072
# Max Epoch Reached[5/5], Step [130/6000], Loss: 0.1688
# Max Epoch Reached[5/5], Step [140/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [150/6000], Loss: 0.0170
# Max Epoch Reached[5/5], Step [160/6000], Loss: 0.1032
# Max Epoch Reached[5/5], Step [170/6000], Loss: 0.0202
# Max Epoch Reached[5/5], Step [180/6000], Loss: 0.0710
# Max Epoch Reached[5/5], Step [190/6000], Loss: 0.1006
# Max Epoch Reached[5/5], Step [200/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [210/6000], Loss: 0.1082
# Max Epoch Reached[5/5], Step [220/6000], Loss: 0.0280
# Max Epoch Reached[5/5], Step [230/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [240/6000], Loss: 0.0232
# Max Epoch Reached[5/5], Step [250/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [260/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [270/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [280/6000], Loss: 0.0033
# Max Epoch Reached[5/5], Step [290/6000], Loss: 0.0061
# Max Epoch Reached[5/5], Step [300/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [310/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [320/6000], Loss: 0.0030
# Max Epoch Reached[5/5], Step [330/6000], Loss: 0.4532
# Max Epoch Reached[5/5], Step [340/6000], Loss: 0.0049
# Max Epoch Reached[5/5], Step [350/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [360/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [370/6000], Loss: 0.0134
# Max Epoch Reached[5/5], Step [380/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [390/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [400/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [410/6000], Loss: 0.0815
# Max Epoch Reached[5/5], Step [420/6000], Loss: 0.0032
# Max Epoch Reached[5/5], Step [430/6000], Loss: 0.0919
# Max Epoch Reached[5/5], Step [440/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [450/6000], Loss: 0.0057
# Max Epoch Reached[5/5], Step [460/6000], Loss: 0.0101
# Max Epoch Reached[5/5], Step [470/6000], Loss: 0.0103
# Max Epoch Reached[5/5], Step [480/6000], Loss: 0.2004
# Max Epoch Reached[5/5], Step [490/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [500/6000], Loss: 0.1139
# Max Epoch Reached[5/5], Step [510/6000], Loss: 0.2082
# Max Epoch Reached[5/5], Step [520/6000], Loss: 0.0023
# Max Epoch Reached[5/5], Step [530/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [540/6000], Loss: 0.1571
# Max Epoch Reached[5/5], Step [550/6000], Loss: 0.1372
# Max Epoch Reached[5/5], Step [560/6000], Loss: 0.2458
# Max Epoch Reached[5/5], Step [570/6000], Loss: 0.3952
# Max Epoch Reached[5/5], Step [580/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [590/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [600/6000], Loss: 0.4137
# Max Epoch Reached[5/5], Step [610/6000], Loss: 0.1366
# Max Epoch Reached[5/5], Step [620/6000], Loss: 0.0113
# Max Epoch Reached[5/5], Step [630/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [640/6000], Loss: 0.0085
# Max Epoch Reached[5/5], Step [650/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [660/6000], Loss: 0.0135
# Max Epoch Reached[5/5], Step [670/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [680/6000], Loss: 0.0170
# Max Epoch Reached[5/5], Step [690/6000], Loss: 0.0440
# Max Epoch Reached[5/5], Step [700/6000], Loss: 0.1408
# Max Epoch Reached[5/5], Step [710/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [720/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [730/6000], Loss: 0.0024
# Max Epoch Reached[5/5], Step [740/6000], Loss: 0.0188
# Max Epoch Reached[5/5], Step [750/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [760/6000], Loss: 0.0487
# Max Epoch Reached[5/5], Step [770/6000], Loss: 0.0049
# Max Epoch Reached[5/5], Step [780/6000], Loss: 0.2752
# Max Epoch Reached[5/5], Step [790/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [800/6000], Loss: 0.0201
# Max Epoch Reached[5/5], Step [810/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [820/6000], Loss: 0.0046
# Max Epoch Reached[5/5], Step [830/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [840/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [850/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [860/6000], Loss: 0.0327
# Max Epoch Reached[5/5], Step [870/6000], Loss: 0.2351
# Max Epoch Reached[5/5], Step [880/6000], Loss: 0.0453
# Max Epoch Reached[5/5], Step [890/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [900/6000], Loss: 0.0063
# Max Epoch Reached[5/5], Step [910/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [920/6000], Loss: 0.0048
# Max Epoch Reached[5/5], Step [930/6000], Loss: 0.1113
# Max Epoch Reached[5/5], Step [940/6000], Loss: 0.0055
# Max Epoch Reached[5/5], Step [950/6000], Loss: 0.0249
# Max Epoch Reached[5/5], Step [960/6000], Loss: 0.0382
# Max Epoch Reached[5/5], Step [970/6000], Loss: 0.0826
# Max Epoch Reached[5/5], Step [980/6000], Loss: 0.0074
# Max Epoch Reached[5/5], Step [990/6000], Loss: 0.0029
# Max Epoch Reached[5/5], Step [1000/6000], Loss: 0.1657
# Max Epoch Reached[5/5], Step [1010/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [1020/6000], Loss: 0.0068
# Max Epoch Reached[5/5], Step [1030/6000], Loss: 0.0253
# Max Epoch Reached[5/5], Step [1040/6000], Loss: 0.0132
# Max Epoch Reached[5/5], Step [1050/6000], Loss: 0.0040
# Max Epoch Reached[5/5], Step [1060/6000], Loss: 0.0027
# Max Epoch Reached[5/5], Step [1070/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [1080/6000], Loss: 0.0900
# Max Epoch Reached[5/5], Step [1090/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [1100/6000], Loss: 0.0067
# Max Epoch Reached[5/5], Step [1110/6000], Loss: 0.0014
# Max Epoch Reached[5/5], Step [1120/6000], Loss: 0.4895
# Max Epoch Reached[5/5], Step [1130/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [1140/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [1150/6000], Loss: 0.4105
# Max Epoch Reached[5/5], Step [1160/6000], Loss: 0.0176
# Max Epoch Reached[5/5], Step [1170/6000], Loss: 0.0014
# Max Epoch Reached[5/5], Step [1180/6000], Loss: 0.0122
# Max Epoch Reached[5/5], Step [1190/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [1200/6000], Loss: 0.1885
# Max Epoch Reached[5/5], Step [1210/6000], Loss: 0.0079
# Max Epoch Reached[5/5], Step [1220/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [1230/6000], Loss: 0.1707
# Max Epoch Reached[5/5], Step [1240/6000], Loss: 0.0030
# Max Epoch Reached[5/5], Step [1250/6000], Loss: 0.0228
# Max Epoch Reached[5/5], Step [1260/6000], Loss: 0.1220
# Max Epoch Reached[5/5], Step [1270/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [1280/6000], Loss: 0.1553
# Max Epoch Reached[5/5], Step [1290/6000], Loss: 0.0789
# Max Epoch Reached[5/5], Step [1300/6000], Loss: 0.1501
# Max Epoch Reached[5/5], Step [1310/6000], Loss: 0.0244
# Max Epoch Reached[5/5], Step [1320/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [1330/6000], Loss: 0.1009
# Max Epoch Reached[5/5], Step [1340/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [1350/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [1360/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [1370/6000], Loss: 0.0065
# Max Epoch Reached[5/5], Step [1380/6000], Loss: 0.0168
# Max Epoch Reached[5/5], Step [1390/6000], Loss: 0.0867
# Max Epoch Reached[5/5], Step [1400/6000], Loss: 0.0876
# Max Epoch Reached[5/5], Step [1410/6000], Loss: 0.0310
# Max Epoch Reached[5/5], Step [1420/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [1430/6000], Loss: 0.0092
# Max Epoch Reached[5/5], Step [1440/6000], Loss: 0.0740
# Max Epoch Reached[5/5], Step [1450/6000], Loss: 0.0936
# Max Epoch Reached[5/5], Step [1460/6000], Loss: 0.0865
# Max Epoch Reached[5/5], Step [1470/6000], Loss: 0.8218
# Max Epoch Reached[5/5], Step [1480/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [1490/6000], Loss: 0.1410
# Max Epoch Reached[5/5], Step [1500/6000], Loss: 0.0131
# Max Epoch Reached[5/5], Step [1510/6000], Loss: 0.0116
# Max Epoch Reached[5/5], Step [1520/6000], Loss: 0.0625
# Max Epoch Reached[5/5], Step [1530/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [1540/6000], Loss: 0.0125
# Max Epoch Reached[5/5], Step [1550/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [1560/6000], Loss: 0.0041
# Max Epoch Reached[5/5], Step [1570/6000], Loss: 0.0258
# Max Epoch Reached[5/5], Step [1580/6000], Loss: 0.0270
# Max Epoch Reached[5/5], Step [1590/6000], Loss: 0.0353
# Max Epoch Reached[5/5], Step [1600/6000], Loss: 0.0263
# Max Epoch Reached[5/5], Step [1610/6000], Loss: 0.0186
# Max Epoch Reached[5/5], Step [1620/6000], Loss: 0.0776
# Max Epoch Reached[5/5], Step [1630/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [1640/6000], Loss: 0.0094
# Max Epoch Reached[5/5], Step [1650/6000], Loss: 0.1653
# Max Epoch Reached[5/5], Step [1660/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [1670/6000], Loss: 0.0033
# Max Epoch Reached[5/5], Step [1680/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [1690/6000], Loss: 0.0086
# Max Epoch Reached[5/5], Step [1700/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [1710/6000], Loss: 0.0116
# Max Epoch Reached[5/5], Step [1720/6000], Loss: 0.0718
# Max Epoch Reached[5/5], Step [1730/6000], Loss: 0.0049
# Max Epoch Reached[5/5], Step [1740/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [1750/6000], Loss: 0.0931
# Max Epoch Reached[5/5], Step [1760/6000], Loss: 0.0598
# Max Epoch Reached[5/5], Step [1770/6000], Loss: 0.0911
# Max Epoch Reached[5/5], Step [1780/6000], Loss: 0.0087
# Max Epoch Reached[5/5], Step [1790/6000], Loss: 0.0326
# Max Epoch Reached[5/5], Step [1800/6000], Loss: 0.0610
# Max Epoch Reached[5/5], Step [1810/6000], Loss: 0.0275
# Max Epoch Reached[5/5], Step [1820/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [1830/6000], Loss: 0.0381
# Max Epoch Reached[5/5], Step [1840/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [1850/6000], Loss: 0.4852
# Max Epoch Reached[5/5], Step [1860/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [1870/6000], Loss: 0.0386
# Max Epoch Reached[5/5], Step [1880/6000], Loss: 0.1024
# Max Epoch Reached[5/5], Step [1890/6000], Loss: 0.4810
# Max Epoch Reached[5/5], Step [1900/6000], Loss: 0.1440
# Max Epoch Reached[5/5], Step [1910/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [1920/6000], Loss: 0.0264
# Max Epoch Reached[5/5], Step [1930/6000], Loss: 0.0112
# Max Epoch Reached[5/5], Step [1940/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [1950/6000], Loss: 0.0078
# Max Epoch Reached[5/5], Step [1960/6000], Loss: 0.0083
# Max Epoch Reached[5/5], Step [1970/6000], Loss: 0.0349
# Max Epoch Reached[5/5], Step [1980/6000], Loss: 0.0039
# Max Epoch Reached[5/5], Step [1990/6000], Loss: 0.1055
# Max Epoch Reached[5/5], Step [2000/6000], Loss: 0.1514
# Max Epoch Reached[5/5], Step [2010/6000], Loss: 0.2428
# Max Epoch Reached[5/5], Step [2020/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2030/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [2040/6000], Loss: 0.1600
# Max Epoch Reached[5/5], Step [2050/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [2060/6000], Loss: 0.0184
# Max Epoch Reached[5/5], Step [2070/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [2080/6000], Loss: 0.0041
# Max Epoch Reached[5/5], Step [2090/6000], Loss: 0.0204
# Max Epoch Reached[5/5], Step [2100/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [2110/6000], Loss: 0.4845
# Max Epoch Reached[5/5], Step [2120/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [2130/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [2140/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [2150/6000], Loss: 0.0183
# Max Epoch Reached[5/5], Step [2160/6000], Loss: 0.0035
# Max Epoch Reached[5/5], Step [2170/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [2180/6000], Loss: 0.0041
# Max Epoch Reached[5/5], Step [2190/6000], Loss: 0.0080
# Max Epoch Reached[5/5], Step [2200/6000], Loss: 0.0072
# Max Epoch Reached[5/5], Step [2210/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [2220/6000], Loss: 0.2962
# Max Epoch Reached[5/5], Step [2230/6000], Loss: 0.0207
# Max Epoch Reached[5/5], Step [2240/6000], Loss: 0.0297
# Max Epoch Reached[5/5], Step [2250/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [2260/6000], Loss: 0.0204
# Max Epoch Reached[5/5], Step [2270/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [2280/6000], Loss: 0.2123
# Max Epoch Reached[5/5], Step [2290/6000], Loss: 0.0097
# Max Epoch Reached[5/5], Step [2300/6000], Loss: 0.3785
# Max Epoch Reached[5/5], Step [2310/6000], Loss: 0.0301
# Max Epoch Reached[5/5], Step [2320/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [2330/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [2340/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [2350/6000], Loss: 0.1114
# Max Epoch Reached[5/5], Step [2360/6000], Loss: 0.0323
# Max Epoch Reached[5/5], Step [2370/6000], Loss: 0.1620
# Max Epoch Reached[5/5], Step [2380/6000], Loss: 0.0219
# Max Epoch Reached[5/5], Step [2390/6000], Loss: 0.5340
# Max Epoch Reached[5/5], Step [2400/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [2410/6000], Loss: 0.0012
# Max Epoch Reached[5/5], Step [2420/6000], Loss: 0.4363
# Max Epoch Reached[5/5], Step [2430/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [2440/6000], Loss: 0.3595
# Max Epoch Reached[5/5], Step [2450/6000], Loss: 0.0112
# Max Epoch Reached[5/5], Step [2460/6000], Loss: 0.0771
# Max Epoch Reached[5/5], Step [2470/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [2480/6000], Loss: 0.0208
# Max Epoch Reached[5/5], Step [2490/6000], Loss: 0.0068
# Max Epoch Reached[5/5], Step [2500/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [2510/6000], Loss: 0.0088
# Max Epoch Reached[5/5], Step [2520/6000], Loss: 0.0765
# Max Epoch Reached[5/5], Step [2530/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [2540/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [2550/6000], Loss: 0.0035
# Max Epoch Reached[5/5], Step [2560/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [2570/6000], Loss: 0.0102
# Max Epoch Reached[5/5], Step [2580/6000], Loss: 0.0125
# Max Epoch Reached[5/5], Step [2590/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [2600/6000], Loss: 0.3557
# Max Epoch Reached[5/5], Step [2610/6000], Loss: 0.0333
# Max Epoch Reached[5/5], Step [2620/6000], Loss: 0.0059
# Max Epoch Reached[5/5], Step [2630/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [2640/6000], Loss: 0.0531
# Max Epoch Reached[5/5], Step [2650/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [2660/6000], Loss: 0.0140
# Max Epoch Reached[5/5], Step [2670/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2680/6000], Loss: 0.0314
# Max Epoch Reached[5/5], Step [2690/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2700/6000], Loss: 0.0379
# Max Epoch Reached[5/5], Step [2710/6000], Loss: 0.0460
# Max Epoch Reached[5/5], Step [2720/6000], Loss: 0.2099
# Max Epoch Reached[5/5], Step [2730/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [2740/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [2750/6000], Loss: 0.1482
# Max Epoch Reached[5/5], Step [2760/6000], Loss: 0.0341
# Max Epoch Reached[5/5], Step [2770/6000], Loss: 0.0155
# Max Epoch Reached[5/5], Step [2780/6000], Loss: 0.0205
# Max Epoch Reached[5/5], Step [2790/6000], Loss: 0.1820
# Max Epoch Reached[5/5], Step [2800/6000], Loss: 0.0170
# Max Epoch Reached[5/5], Step [2810/6000], Loss: 0.0458
# Max Epoch Reached[5/5], Step [2820/6000], Loss: 0.0618
# Max Epoch Reached[5/5], Step [2830/6000], Loss: 0.0014
# Max Epoch Reached[5/5], Step [2840/6000], Loss: 0.0094
# Max Epoch Reached[5/5], Step [2850/6000], Loss: 0.0167
# Max Epoch Reached[5/5], Step [2860/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [2870/6000], Loss: 0.0035
# Max Epoch Reached[5/5], Step [2880/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [2890/6000], Loss: 0.2657
# Max Epoch Reached[5/5], Step [2900/6000], Loss: 0.0356
# Max Epoch Reached[5/5], Step [2910/6000], Loss: 0.1295
# Max Epoch Reached[5/5], Step [2920/6000], Loss: 0.0130
# Max Epoch Reached[5/5], Step [2930/6000], Loss: 0.1864
# Max Epoch Reached[5/5], Step [2940/6000], Loss: 0.1783
# Max Epoch Reached[5/5], Step [2950/6000], Loss: 0.0466
# Max Epoch Reached[5/5], Step [2960/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [2970/6000], Loss: 0.0471
# Max Epoch Reached[5/5], Step [2980/6000], Loss: 0.2919
# Max Epoch Reached[5/5], Step [2990/6000], Loss: 0.0491
# Max Epoch Reached[5/5], Step [3000/6000], Loss: 0.0356
# Max Epoch Reached[5/5], Step [3010/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [3020/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [3030/6000], Loss: 0.0058
# Max Epoch Reached[5/5], Step [3040/6000], Loss: 0.0040
# Max Epoch Reached[5/5], Step [3050/6000], Loss: 0.6685
# Max Epoch Reached[5/5], Step [3060/6000], Loss: 0.0409
# Max Epoch Reached[5/5], Step [3070/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [3080/6000], Loss: 0.0637
# Max Epoch Reached[5/5], Step [3090/6000], Loss: 0.0139
# Max Epoch Reached[5/5], Step [3100/6000], Loss: 0.0763
# Max Epoch Reached[5/5], Step [3110/6000], Loss: 0.0656
# Max Epoch Reached[5/5], Step [3120/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [3130/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [3140/6000], Loss: 0.0570
# Max Epoch Reached[5/5], Step [3150/6000], Loss: 0.1416
# Max Epoch Reached[5/5], Step [3160/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [3170/6000], Loss: 0.0228
# Max Epoch Reached[5/5], Step [3180/6000], Loss: 0.0031
# Max Epoch Reached[5/5], Step [3190/6000], Loss: 0.0250
# Max Epoch Reached[5/5], Step [3200/6000], Loss: 0.0572
# Max Epoch Reached[5/5], Step [3210/6000], Loss: 0.0333
# Max Epoch Reached[5/5], Step [3220/6000], Loss: 0.2817
# Max Epoch Reached[5/5], Step [3230/6000], Loss: 0.0063
# Max Epoch Reached[5/5], Step [3240/6000], Loss: 0.1226
# Max Epoch Reached[5/5], Step [3250/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3260/6000], Loss: 0.0198
# Max Epoch Reached[5/5], Step [3270/6000], Loss: 0.0110
# Max Epoch Reached[5/5], Step [3280/6000], Loss: 0.0284
# Max Epoch Reached[5/5], Step [3290/6000], Loss: 0.0044
# Max Epoch Reached[5/5], Step [3300/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [3310/6000], Loss: 0.0567
# Max Epoch Reached[5/5], Step [3320/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [3330/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3340/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [3350/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [3360/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [3370/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [3380/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [3390/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3400/6000], Loss: 0.0398
# Max Epoch Reached[5/5], Step [3410/6000], Loss: 0.0055
# Max Epoch Reached[5/5], Step [3420/6000], Loss: 0.0119
# Max Epoch Reached[5/5], Step [3430/6000], Loss: 0.0446
# Max Epoch Reached[5/5], Step [3440/6000], Loss: 0.1975
# Max Epoch Reached[5/5], Step [3450/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [3460/6000], Loss: 0.0690
# Max Epoch Reached[5/5], Step [3470/6000], Loss: 0.0594
# Max Epoch Reached[5/5], Step [3480/6000], Loss: 0.2634
# Max Epoch Reached[5/5], Step [3490/6000], Loss: 0.0764
# Max Epoch Reached[5/5], Step [3500/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [3510/6000], Loss: 0.0058
# Max Epoch Reached[5/5], Step [3520/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [3530/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [3540/6000], Loss: 0.1512
# Max Epoch Reached[5/5], Step [3550/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [3560/6000], Loss: 0.0195
# Max Epoch Reached[5/5], Step [3570/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [3580/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [3590/6000], Loss: 0.2725
# Max Epoch Reached[5/5], Step [3600/6000], Loss: 0.2262
# Max Epoch Reached[5/5], Step [3610/6000], Loss: 0.0012
# Max Epoch Reached[5/5], Step [3620/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [3630/6000], Loss: 0.0149
# Max Epoch Reached[5/5], Step [3640/6000], Loss: 0.0765
# Max Epoch Reached[5/5], Step [3650/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [3660/6000], Loss: 0.0528
# Max Epoch Reached[5/5], Step [3670/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [3680/6000], Loss: 0.0024
# Max Epoch Reached[5/5], Step [3690/6000], Loss: 0.0060
# Max Epoch Reached[5/5], Step [3700/6000], Loss: 0.0345
# Max Epoch Reached[5/5], Step [3710/6000], Loss: 0.1055
# Max Epoch Reached[5/5], Step [3720/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [3730/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [3740/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [3750/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [3760/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [3770/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [3780/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [3790/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3800/6000], Loss: 0.3603
# Max Epoch Reached[5/5], Step [3810/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [3820/6000], Loss: 0.0184
# Max Epoch Reached[5/5], Step [3830/6000], Loss: 0.0053
# Max Epoch Reached[5/5], Step [3840/6000], Loss: 0.0117
# Max Epoch Reached[5/5], Step [3850/6000], Loss: 0.0069
# Max Epoch Reached[5/5], Step [3860/6000], Loss: 0.0399
# Max Epoch Reached[5/5], Step [3870/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [3880/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [3890/6000], Loss: 0.0443
# Max Epoch Reached[5/5], Step [3900/6000], Loss: 0.0087
# Max Epoch Reached[5/5], Step [3910/6000], Loss: 0.4166
# Max Epoch Reached[5/5], Step [3920/6000], Loss: 0.0113
# Max Epoch Reached[5/5], Step [3930/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [3940/6000], Loss: 0.1570
# Max Epoch Reached[5/5], Step [3950/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [3960/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [3970/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [3980/6000], Loss: 0.0548
# Max Epoch Reached[5/5], Step [3990/6000], Loss: 0.1782
# Max Epoch Reached[5/5], Step [4000/6000], Loss: 0.0046
# Max Epoch Reached[5/5], Step [4010/6000], Loss: 0.1235
# Max Epoch Reached[5/5], Step [4020/6000], Loss: 0.0032
# Max Epoch Reached[5/5], Step [4030/6000], Loss: 0.2011
# Max Epoch Reached[5/5], Step [4040/6000], Loss: 0.0058
# Max Epoch Reached[5/5], Step [4050/6000], Loss: 0.0034
# Max Epoch Reached[5/5], Step [4060/6000], Loss: 0.0383
# Max Epoch Reached[5/5], Step [4070/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [4080/6000], Loss: 0.0112
# Max Epoch Reached[5/5], Step [4090/6000], Loss: 0.0312
# Max Epoch Reached[5/5], Step [4100/6000], Loss: 0.1543
# Max Epoch Reached[5/5], Step [4110/6000], Loss: 0.0246
# Max Epoch Reached[5/5], Step [4120/6000], Loss: 0.1002
# Max Epoch Reached[5/5], Step [4130/6000], Loss: 0.0071
# Max Epoch Reached[5/5], Step [4140/6000], Loss: 0.0190
# Max Epoch Reached[5/5], Step [4150/6000], Loss: 0.0466
# Max Epoch Reached[5/5], Step [4160/6000], Loss: 0.0179
# Max Epoch Reached[5/5], Step [4170/6000], Loss: 0.0182
# Max Epoch Reached[5/5], Step [4180/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [4190/6000], Loss: 0.0032
# Max Epoch Reached[5/5], Step [4200/6000], Loss: 0.0040
# Max Epoch Reached[5/5], Step [4210/6000], Loss: 0.0161
# Max Epoch Reached[5/5], Step [4220/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [4230/6000], Loss: 0.0132
# Max Epoch Reached[5/5], Step [4240/6000], Loss: 0.0202
# Max Epoch Reached[5/5], Step [4250/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [4260/6000], Loss: 0.0099
# Max Epoch Reached[5/5], Step [4270/6000], Loss: 0.0140
# Max Epoch Reached[5/5], Step [4280/6000], Loss: 0.0574
# Max Epoch Reached[5/5], Step [4290/6000], Loss: 0.0193
# Max Epoch Reached[5/5], Step [4300/6000], Loss: 0.0213
# Max Epoch Reached[5/5], Step [4310/6000], Loss: 0.0566
# Max Epoch Reached[5/5], Step [4320/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [4330/6000], Loss: 0.0569
# Max Epoch Reached[5/5], Step [4340/6000], Loss: 0.2399
# Max Epoch Reached[5/5], Step [4350/6000], Loss: 0.0406
# Max Epoch Reached[5/5], Step [4360/6000], Loss: 0.2951
# Max Epoch Reached[5/5], Step [4370/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [4380/6000], Loss: 0.0477
# Max Epoch Reached[5/5], Step [4390/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [4400/6000], Loss: 0.1443
# Max Epoch Reached[5/5], Step [4410/6000], Loss: 0.4821
# Max Epoch Reached[5/5], Step [4420/6000], Loss: 0.0248
# Max Epoch Reached[5/5], Step [4430/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [4440/6000], Loss: 0.0100
# Max Epoch Reached[5/5], Step [4450/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [4460/6000], Loss: 0.1287
# Max Epoch Reached[5/5], Step [4470/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [4480/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [4490/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [4500/6000], Loss: 0.0110
# Max Epoch Reached[5/5], Step [4510/6000], Loss: 0.0385
# Max Epoch Reached[5/5], Step [4520/6000], Loss: 0.0080
# Max Epoch Reached[5/5], Step [4530/6000], Loss: 0.0826
# Max Epoch Reached[5/5], Step [4540/6000], Loss: 0.0299
# Max Epoch Reached[5/5], Step [4550/6000], Loss: 0.0300
# Max Epoch Reached[5/5], Step [4560/6000], Loss: 0.0406
# Max Epoch Reached[5/5], Step [4570/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [4580/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [4590/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [4600/6000], Loss: 0.3733
# Max Epoch Reached[5/5], Step [4610/6000], Loss: 0.0276
# Max Epoch Reached[5/5], Step [4620/6000], Loss: 0.4210
# Max Epoch Reached[5/5], Step [4630/6000], Loss: 0.1794
# Max Epoch Reached[5/5], Step [4640/6000], Loss: 0.0371
# Max Epoch Reached[5/5], Step [4650/6000], Loss: 0.0089
# Max Epoch Reached[5/5], Step [4660/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [4670/6000], Loss: 0.0734
# Max Epoch Reached[5/5], Step [4680/6000], Loss: 0.1098
# Max Epoch Reached[5/5], Step [4690/6000], Loss: 0.0134
# Max Epoch Reached[5/5], Step [4700/6000], Loss: 0.1496
# Max Epoch Reached[5/5], Step [4710/6000], Loss: 0.0046
# Max Epoch Reached[5/5], Step [4720/6000], Loss: 0.3175
# Max Epoch Reached[5/5], Step [4730/6000], Loss: 0.0556
# Max Epoch Reached[5/5], Step [4740/6000], Loss: 0.1570
# Max Epoch Reached[5/5], Step [4750/6000], Loss: 0.0304
# Max Epoch Reached[5/5], Step [4760/6000], Loss: 0.0822
# Max Epoch Reached[5/5], Step [4770/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [4780/6000], Loss: 0.4569
# Max Epoch Reached[5/5], Step [4790/6000], Loss: 0.0165
# Max Epoch Reached[5/5], Step [4800/6000], Loss: 0.0190
# Max Epoch Reached[5/5], Step [4810/6000], Loss: 0.0238
# Max Epoch Reached[5/5], Step [4820/6000], Loss: 0.0023
# Max Epoch Reached[5/5], Step [4830/6000], Loss: 0.0106
# Max Epoch Reached[5/5], Step [4840/6000], Loss: 0.0234
# Max Epoch Reached[5/5], Step [4850/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [4860/6000], Loss: 0.0341
# Max Epoch Reached[5/5], Step [4870/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [4880/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [4890/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [4900/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [4910/6000], Loss: 0.0088
# Max Epoch Reached[5/5], Step [4920/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [4930/6000], Loss: 0.0166
# Max Epoch Reached[5/5], Step [4940/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [4950/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [4960/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [4970/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [4980/6000], Loss: 0.0024
# Max Epoch Reached[5/5], Step [4990/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [5000/6000], Loss: 0.0101
# Max Epoch Reached[5/5], Step [5010/6000], Loss: 0.0219
# Max Epoch Reached[5/5], Step [5020/6000], Loss: 0.0045
# Max Epoch Reached[5/5], Step [5030/6000], Loss: 0.0277
# Max Epoch Reached[5/5], Step [5040/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [5050/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [5060/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [5070/6000], Loss: 0.2671
# Max Epoch Reached[5/5], Step [5080/6000], Loss: 0.0533
# Max Epoch Reached[5/5], Step [5090/6000], Loss: 0.1255
# Max Epoch Reached[5/5], Step [5100/6000], Loss: 0.0059
# Max Epoch Reached[5/5], Step [5110/6000], Loss: 0.0192
# Max Epoch Reached[5/5], Step [5120/6000], Loss: 0.0764
# Max Epoch Reached[5/5], Step [5130/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [5140/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [5150/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [5160/6000], Loss: 0.0188
# Max Epoch Reached[5/5], Step [5170/6000], Loss: 0.1182
# Max Epoch Reached[5/5], Step [5180/6000], Loss: 0.0121
# Max Epoch Reached[5/5], Step [5190/6000], Loss: 0.0034
# Max Epoch Reached[5/5], Step [5200/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [5210/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [5220/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [5230/6000], Loss: 0.0023
# Max Epoch Reached[5/5], Step [5240/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [5250/6000], Loss: 0.0252
# Max Epoch Reached[5/5], Step [5260/6000], Loss: 0.0656
# Max Epoch Reached[5/5], Step [5270/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [5280/6000], Loss: 0.1676
# Max Epoch Reached[5/5], Step [5290/6000], Loss: 0.0618
# Max Epoch Reached[5/5], Step [5300/6000], Loss: 0.0027
# Max Epoch Reached[5/5], Step [5310/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [5320/6000], Loss: 0.1004
# Max Epoch Reached[5/5], Step [5330/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [5340/6000], Loss: 0.0140
# Max Epoch Reached[5/5], Step [5350/6000], Loss: 0.4096
# Max Epoch Reached[5/5], Step [5360/6000], Loss: 0.0196
# Max Epoch Reached[5/5], Step [5370/6000], Loss: 0.0158
# Max Epoch Reached[5/5], Step [5380/6000], Loss: 0.0327
# Max Epoch Reached[5/5], Step [5390/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [5400/6000], Loss: 0.0087
# Max Epoch Reached[5/5], Step [5410/6000], Loss: 0.1018
# Max Epoch Reached[5/5], Step [5420/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [5430/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [5440/6000], Loss: 0.0098
# Max Epoch Reached[5/5], Step [5450/6000], Loss: 0.0419
# Max Epoch Reached[5/5], Step [5460/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [5470/6000], Loss: 0.0027
# Max Epoch Reached[5/5], Step [5480/6000], Loss: 0.2264
# Max Epoch Reached[5/5], Step [5490/6000], Loss: 0.4146
# Max Epoch Reached[5/5], Step [5500/6000], Loss: 0.0136
# Max Epoch Reached[5/5], Step [5510/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [5520/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [5530/6000], Loss: 0.0174
# Max Epoch Reached[5/5], Step [5540/6000], Loss: 0.0162
# Max Epoch Reached[5/5], Step [5550/6000], Loss: 0.2752
# Max Epoch Reached[5/5], Step [5560/6000], Loss: 0.0985
# Max Epoch Reached[5/5], Step [5570/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [5580/6000], Loss: 0.0199
# Max Epoch Reached[5/5], Step [5590/6000], Loss: 0.0770
# Max Epoch Reached[5/5], Step [5600/6000], Loss: 0.0024
# Max Epoch Reached[5/5], Step [5610/6000], Loss: 0.0455
# Max Epoch Reached[5/5], Step [5620/6000], Loss: 0.0446
# Max Epoch Reached[5/5], Step [5630/6000], Loss: 0.0397
# Max Epoch Reached[5/5], Step [5640/6000], Loss: 0.3402
# Max Epoch Reached[5/5], Step [5650/6000], Loss: 0.0189
# Max Epoch Reached[5/5], Step [5660/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [5670/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [5680/6000], Loss: 0.0072
# Max Epoch Reached[5/5], Step [5690/6000], Loss: 0.1691
# Max Epoch Reached[5/5], Step [5700/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [5710/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [5720/6000], Loss: 0.1770
# Max Epoch Reached[5/5], Step [5730/6000], Loss: 0.0344
# Max Epoch Reached[5/5], Step [5740/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [5750/6000], Loss: 0.0068
# Max Epoch Reached[5/5], Step [5760/6000], Loss: 0.0192
# Max Epoch Reached[5/5], Step [5770/6000], Loss: 0.0413
# Max Epoch Reached[5/5], Step [5780/6000], Loss: 0.0088
# Max Epoch Reached[5/5], Step [5790/6000], Loss: 0.0524
# Max Epoch Reached[5/5], Step [5800/6000], Loss: 0.0217
# Max Epoch Reached[5/5], Step [5810/6000], Loss: 0.0108
# Max Epoch Reached[5/5], Step [5820/6000], Loss: 0.0053
# Max Epoch Reached[5/5], Step [5830/6000], Loss: 0.0092
# Max Epoch Reached[5/5], Step [5840/6000], Loss: 0.0199
# Max Epoch Reached[5/5], Step [5850/6000], Loss: 0.0877
# Max Epoch Reached[5/5], Step [5860/6000], Loss: 0.0108
# Max Epoch Reached[5/5], Step [5870/6000], Loss: 0.0012
# Max Epoch Reached[5/5], Step [5880/6000], Loss: 0.0077
# Max Epoch Reached[5/5], Step [5890/6000], Loss: 0.0137
# Max Epoch Reached[5/5], Step [5900/6000], Loss: 0.0130
# Max Epoch Reached[5/5], Step [5910/6000], Loss: 0.0146
# Max Epoch Reached[5/5], Step [5920/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [5930/6000], Loss: 0.0170
# Max Epoch Reached[5/5], Step [5940/6000], Loss: 0.0047
# Max Epoch Reached[5/5], Step [5950/6000], Loss: 0.0057
# Max Epoch Reached[5/5], Step [5960/6000], Loss: 0.8130
# Max Epoch Reached[5/5], Step [5970/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [5980/6000], Loss: 0.0321
# Max Epoch Reached[5/5], Step [5990/6000], Loss: 0.0340
# Max Epoch Reached[5/5], Step [6000/6000], Loss: 0.0091
# Train Avg loss: tensor(1.0540, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 97.63% & Test Loss: 0.07449228372256039
# Train Avg loss: tensor(1.4537, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1979, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1412, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1075, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/156], Loss: 0.1377
# Max Epoch Reached[5/5], Step [20/156], Loss: 0.1195
# Max Epoch Reached[5/5], Step [30/156], Loss: 0.1441
# Max Epoch Reached[5/5], Step [40/156], Loss: 0.0560
# Max Epoch Reached[5/5], Step [50/156], Loss: 0.1208
# Max Epoch Reached[5/5], Step [60/156], Loss: 0.0924
# Max Epoch Reached[5/5], Step [70/156], Loss: 0.0775
# Max Epoch Reached[5/5], Step [80/156], Loss: 0.0958
# Max Epoch Reached[5/5], Step [90/156], Loss: 0.1055
# Max Epoch Reached[5/5], Step [100/156], Loss: 0.0821
# Max Epoch Reached[5/5], Step [110/156], Loss: 0.0965
# Max Epoch Reached[5/5], Step [120/156], Loss: 0.0874
# Max Epoch Reached[5/5], Step [130/156], Loss: 0.0831
# Max Epoch Reached[5/5], Step [140/156], Loss: 0.0840
# Max Epoch Reached[5/5], Step [150/156], Loss: 0.0443
# Train Avg loss: tensor(1.0865, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 97.41% & Test Loss: 0.08956824397095121
# Train Avg loss: tensor(1.6096, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2507, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1913, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1511, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/79], Loss: 0.1346
# Max Epoch Reached[5/5], Step [20/79], Loss: 0.1259
# Max Epoch Reached[5/5], Step [30/79], Loss: 0.1196
# Max Epoch Reached[5/5], Step [40/79], Loss: 0.1454
# Max Epoch Reached[5/5], Step [50/79], Loss: 0.1010
# Max Epoch Reached[5/5], Step [60/79], Loss: 0.1340
# Max Epoch Reached[5/5], Step [70/79], Loss: 0.1005
# Train Avg loss: tensor(1.1258, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 96.59% & Test Loss: 0.12085193315786975
# Train Avg loss: tensor(1.7443, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2877, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2268, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1855, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/53], Loss: 0.1589
# Max Epoch Reached[5/5], Step [20/53], Loss: 0.1510
# Max Epoch Reached[5/5], Step [30/53], Loss: 0.1337
# Max Epoch Reached[5/5], Step [40/53], Loss: 0.1481
# Max Epoch Reached[5/5], Step [50/53], Loss: 0.1314
# Train Avg loss: tensor(1.1562, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 95.91% & Test Loss: 0.14184723794460297
# Train Avg loss: tensor(1.8686, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.3174, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2560, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2161, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/40], Loss: 0.1709
# Max Epoch Reached[5/5], Step [20/40], Loss: 0.1779
# Max Epoch Reached[5/5], Step [30/40], Loss: 0.1741
# Max Epoch Reached[5/5], Step [40/40], Loss: 0.1772
# Train Avg loss: tensor(1.1838, grad_fn=<AddBackward0>)
# Accuracy of the network on the test images: 95.07% & Test Loss: 0.16762679921729223

# %%
def meanScore(dataArr):
    meanModelData = []
    for i in range (len(dataArr)):
        meanScore = np.mean(dataArr[i])
        meanModelData.append(meanScore)
    return meanModelData

def minScore(dataArr):
    minModelScore = []
    for i in range (len(dataArr)):
        minScore = np.mean(dataArr[i])
        minModelScore.append(minScore)
    return minModelScore

def maxScore(dataArr):
    maxModelScore = []
    for i in range (len(dataArr)):
        maxScore = np.max(dataArr[i])
        maxModelScore.append(maxScore)
    return maxModelScore

# %%
fig,ax=plt.subplots()
ax.plot(batchArr,minScore(modelsTrainLossArr),color="Blue", marker="o",linestyle='dashed')
ax.plot(batchArr,modelsTestLossArr,color="Blue", marker="v")
ax.legend(['Train Loss','Test Loss'],loc="upper right")
ax.set_xlabel("Batch",color="Green")
#ax.set_xscale('log')
ax.set_ylabel("CrossEntropy Loss",color = "blue")
ax.set_title("Loss,Sensitivity Vs Batch Size",color="g")

ax2=ax.twinx()
ax2.plot(batchArr,minScore(modelsSensitivityArr),color="red")
ax2.set_xlabel("Batch",color="Green")
ax2.set_ylabel("Sensitivity",color = "red")
ax2.legend(['Sensitivity'],loc="center left")

plt.show()

# %%
fig,ax=plt.subplots()
ax.plot(batchArr,minScore(modelsTrainAccArr),color="Blue", marker="o",linestyle='dashed')
ax.plot(batchArr,modelsTestAccArr,color="Blue", marker="v")
ax.legend(['Train Acc','Test Acc'],loc="upper right")
ax.set_xlabel("Batch",color="Green")
#ax.set_xscale('log')
ax.set_ylabel("Accuracy",color = "blue")
ax.set_title("Accuracy,Sensitivity Vs Batch Size",color="g")

ax2=ax.twinx()
ax2.plot(batchArr,minScore(modelsSensitivityArr),color="red")
ax2.set_xlabel("Batch",color="Green")
ax2.set_ylabel("Sensitivity",color = "red")
ax2.legend(['Sensitivity'],loc="center left")

plt.show()
